# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests

url = "https://my.api.mockaroo.com/student_score_dataset.json?key=c7292250"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print("Data fetched successfully!")
else:
    print("Error:", response.status_code)

df = pd.DataFrame(data)

df.head()
# Out:
# Data fetched successfully!
#    student_id         student_name  score           subject
# 0           1        Nichole Liver     86  Computer Science
# 1           2  Clementina Stephens     52             Maths
# 2           3  Nicholle Josofovitz     98           English
# 3           4    Smitty Magrannell     41  Computer Science
# 4           5     Arlin MacIlhargy     76             Maths

# %%
df.describe()
# Out:
#        student_id       score
# count    10.00000   10.000000
# mean      5.50000   78.700000
# std       3.02765   20.505013
# min       1.00000   42.000000
# 25%       3.25000   77.500000
# 50%       5.50000   84.500000
# 75%       7.75000   89.500000
# max      10.00000  100.000000

# %%
average_score = df["score"].mean()

print(f"Average Score: {average_score:.2f}")
# Out:
# Average Score: 58.70

# %%
plt.figure(figsize=(20,6))

plt.bar(df["student_name"], df["score"])

plt.title("Student Test Scores")
plt.xlabel("Students")
plt.ylabel("Score")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
