# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Users_data.csv")

df.head()
# Out:
#            name            email
# 0  Rahul Sharma  rahul@gmail.com
# 1   Priya Verma  priya@gmail.com
# 2    Amit Singh   amit@gmail.com
# 3    Neha Gupta   neha@gmail.com
# 4   Rohit Kumar  rohit@gmail.com

# %%
import sqlite3

# %%
conn = sqlite3.connect("Users_data.db")

cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    email TEXT
)
""")

conn.commit()

# %%
for _, row in df.iterrows():
    cursor.execute(
        "INSERT INTO users (name, email) VALUES (?, ?)",
        (row["name"], row["email"])
    )

conn.commit()

# %%
cursor.execute("SELECT * FROM users")

records = cursor.fetchall()

for record in records:
    print(record)
# Out:
# (1, 'Rahul Sharma', 'rahul@gmail.com')
# (2, 'Priya Verma', 'priya@gmail.com')
# (3, 'Amit Singh', 'amit@gmail.com')
# (4, 'Neha Gupta', 'neha@gmail.com')
# (5, 'Rohit Kumar', 'rohit@gmail.com')
# (6, 'Raj Kumar', 'raj.kumar@gmail.com')
# (7, 'Vedang Sinha', 'vedang.sinha@gmail.com')
# (8, 'Kashish Mehra', 'mehrakashish@gmail.com')
# (9, 'Himang Chopra', 'himang.chopra@gmail.com')
# (10, 'Ruchika Patel', 'patelruchika@gmail.com')

# %%
conn.close()
